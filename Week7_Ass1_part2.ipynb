# %%
import pandas as pd 
df=pd.read_excel("CLF01.xls")
df.head()
# Out:
#         Areaname  STCOU  CLF010190F  CLF010190D  CLF010190N1  CLF010190N2  \
# 0  UNITED STATES      0           0   125840000            0            0
# 1        ALABAMA   1000           0     1888744            0            0
# 2    Autauga, AL   1001           0       16742            0            0
# 3    Baldwin, AL   1003           0       46350            0            0
# 4    Barbour, AL   1005           0       11380            0            0
#
#    CLF010191F  CLF010191D  CLF010191N1  CLF010191N2  ...  CLF010197N1  \
# 0           0   126346000            0            0  ...            0
# 1           0     1907068            0            0  ...            0
# 2           0       16810            0            0  ...            0
# 3           0       49090            0            0  ...            0
# 4           0       11543            0            0  ...            0
#
#    CLF010197N2  CLF010198F  CLF010198D  CLF010198N1  CLF010198N2  CLF010199F  \
# ...
